# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
exp_vals = [1400,600,300,410,250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car","Other utilities"]

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels,radius=1.5,autopct='%.2f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x2320e30e490>,
# ...
#  [Text(0.13992984610809037, 1.6440558500757103, 'Home Rent'),
#   Text(-1.4733277336164126, -0.7428360447344526, 'Food'),
#   Text(-0.2442705692690205, -1.6318185833569212, 'Phone/Internet Bill'),
#   Text(0.9384150502286911, -1.3571577629385183, 'Car'),
#   Text(1.5922567846149476, -0.43268733728602315, 'Other utilities')],
#  [Text(0.07632537060441291, 0.8967577364049328, '47.30%'),
#   Text(-0.8036333092453158, -0.40518329712788315, '20.27%'),
#   Text(-0.1332384923285566, -0.8900828636492296, '10.14%'),
#   Text(0.511862754670195, -0.7402678706937371, '13.85%'),
#   Text(0.8685037006990621, -0.2360112748832853, '8.45%')])

# %%
plt.axis("equal")
plt.title("Expense")
color = ['red','yellow','green','black','pink']
plt.legend(loc='upper right',labels=exp_labels )
plt.pie(exp_vals,labels=exp_labels,radius=1,colors=color,autopct='%.2f%%',shadow=True,explode=[0,0.1,0,0,0],startangle=45)
# Out:
# ([<matplotlib.patches.Wedge at 0x2320d44b5b0>,
# ...
#  [Text(-0.7090517981096851, 0.8409789222075797, 'Home Rent'),
#   Text(-0.37566227404279884, -1.1396832261031982, 'Food'),
#   Text(0.6540964066556544, -0.8843969079548847, 'Phone/Internet Bill'),
#   Text(1.0821434019320089, -0.19739720781971273, 'Car'),
#   Text(0.9545678134133436, 0.546626279642013, 'Other utilities')],
#  [Text(-0.3867555262416464, 0.4587157757495889, '47.30%'),
#   Text(-0.21913632652496595, -0.6648152152268655, '20.27%'),
#   Text(0.3567798581758115, -0.48239831342993705, '10.14%'),
#   Text(0.5902600374174594, -0.10767120426529785, '13.85%'),
#   Text(0.5206733527709146, 0.2981597888956435, '8.45%')])
